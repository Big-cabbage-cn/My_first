# %% [markdown]
# # ViT Tiny-ImageNet Training on Colab
#
# 在 Colab T4 GPU 上训练 Vision Transformer

# %% [markdown]
# ## 1. 检查 GPU

# %%
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# !nvidia-smi
# Out:
# CUDA available: False
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# ## 2. 克隆项目代码

# %%
# !git clone https://github.com/Big-cabbage-cn/My_first.git
# %cd My_first

# %% [markdown]
# ## 3. 安装依赖

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 4. 准备数据集

# %%
# 下载并准备 Tiny-ImageNet 数据
# !python prepare_data.py

# %% [markdown]
# ## 5. 开始训练

# %%
# 使用 GPU 训练模型
# !python main.py train --config configs/vit_tiny_imagenet.yaml

# %% [markdown]
# ## 6. 查看训练结果（可选）

# %%
# 加载 TensorBoard 查看训练曲线
# %load_ext tensorboard
# %tensorboard --logdir runs/
